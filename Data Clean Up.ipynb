# %%
import pandas as pd
import os
import altair as alt

# %%
current_directory = os.getcwd()

# List CSV files in the current directory
csv_files = [file for file in os.listdir(current_directory) if file.endswith('.csv')]

combined_data = pd.DataFrame()

for file in csv_files:
    data = pd.read_csv(file)
    combined_data = combined_data.append(data, ignore_index=True)

# %%
combined_data.head()
# Out:
#   most_recent_observation most_recent_observation_type  common_name  \
# 0               6/17/2020               inventory_date       Locust
# 1                6/9/2020               inventory_date          Oak
# 2                6/3/2020               inventory_date          Ash
# 3                6/3/2020               inventory_date  Scotch pine
# 4               5/29/2020               inventory_date  Honeylocust
#
#          scientific_name         city       state  longitude_coordinate  \
# 0                    NaN  Albuquerque  New Mexico           -106.568366
# 1                Quercus  Albuquerque  New Mexico           -106.655037
# 2               Fraxinus  Albuquerque  New Mexico           -106.581127
# 3       Pinus sylvestris  Albuquerque  New Mexico           -106.575056
# 4  Gleditsia triacanthos  Albuquerque  New Mexico           -106.716539
#
#    latitude_coordinate                         address   condition  ...  \
# 0            35.060456                             NaN  dead/dying  ...
# 1            35.139272   1641 Tierra Del Rio Northwest         NaN  ...
# 2            35.052176       Us Veterans Hospital Loop  dead/dying  ...
# 3            35.052450  1606 San Pedro Drive Southeast  dead/dying  ...
# 4            35.149632    5700 Bogart Street Northwest        good  ...
#
#    zipcode neighborhood location_name ward district overhead_utility  \
# 0      NaN          NaN           NaN  NaN      NaN              NaN
# 1      NaN          NaN           NaN  NaN      NaN              NaN
# 2      NaN          NaN           NaN  NaN      NaN              NaN
# 3      NaN          NaN           NaN  NaN      NaN              NaN
# 4      NaN          NaN           NaN  NaN      NaN              NaN
#
#    diameter_breast_height_CM percent_population column_name definition
# 0                        NaN                NaN         NaN        NaN
# 1                        NaN                NaN         NaN        NaN
# 2                        NaN                NaN         NaN        NaN
# 3                        NaN                NaN         NaN        NaN
# 4                        NaN                NaN         NaN        NaN
#
# [5 rows x 30 columns]

# %%
drop_columns = combined_data.columns[12:]

# Drop the columns
combined_data = combined_data.drop(columns=drop_columns)

# %%
combined_data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# No charts were generated by quickchart

# %%
df2 = combined_data.fillna("null")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame

# %%
df2 = df2.drop_duplicates()

# %%
df2.head()
# Out:
#   most_recent_observation most_recent_observation_type  common_name  \
# 0               6/17/2020               inventory_date       Locust
# 1                6/9/2020               inventory_date          Oak
# 2                6/3/2020               inventory_date          Ash
# 3                6/3/2020               inventory_date  Scotch pine
# 4               5/29/2020               inventory_date  Honeylocust
#
#          scientific_name         city       state longitude_coordinate  \
# 0                   null  Albuquerque  New Mexico          -106.568366
# 1                Quercus  Albuquerque  New Mexico          -106.655037
# 2               Fraxinus  Albuquerque  New Mexico          -106.581127
# 3       Pinus sylvestris  Albuquerque  New Mexico          -106.575056
# 4  Gleditsia triacanthos  Albuquerque  New Mexico          -106.716539
#
#   latitude_coordinate                         address   condition  height_M  \
# 0           35.060456                            null  dead/dying      null
# 1           35.139272   1641 Tierra Del Rio Northwest        null      null
# 2           35.052176       Us Veterans Hospital Loop  dead/dying      null
# 3            35.05245  1606 San Pedro Drive Southeast  dead/dying  147.6378
# 4           35.149632    5700 Bogart Street Northwest        good   98.4252
#
#        native
# 0     no_info
# 1     no_info
# 2     no_info
# 3  introduced
# 4  introduced

# %%
df2.to_csv('combined_data.csv', index=False)
